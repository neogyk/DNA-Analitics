# %%
import pandas as pd
import numpy as np
import os

# %%
dataPath = "C:/Users/i.podmokov/Desktop/Info Flask/EDIT/TotalStatistics/"

# %%
#os.listdir(dataPath)

# %%
# Print our DataFrame
df = pd.read_csv("C:/Users/i.podmokov/Desktop/Info Flask/EDIT/TotalStatistics/31.05.2016/REEL_01.csv")

# %%
#Add custom Column DataFill same as folder of .csv file
df['FillDate'] = np.where(df['Reel']=='REEL_01','31.05.2016','Null')

df['Seq'] = df['Seq'].astype(str)
df['Duration'] = df['Duration'].astype(str)

# %%
#Divide df on two different data frames that willl be represented as two different sql tables
df_1 = df[['Name','Shot','Seq','Reel','StartDate','EndDate','Duration']]
df_2 = df[['Status','FillDate']]

# %%
#Fill all attrributes NAN
df_1 = df_1.fillna('Not defined')
df_2 = df_2.fillna('Not defined')

# %%
#Print DataFrame
df_1
# Out:
#               Name      Shot Seq     Reel            StartDate  \
# 0        Animation  SHOT_010  20  REEL_01  2015-09-03 00:00:00
# 1              Fur  SHOT_010  20  REEL_01  2015-12-10 00:00:00
# 2         Assemble  SHOT_010  20  REEL_01          Not defined
# 3            Cloth  SHOT_010  20  REEL_01  2015-12-07 00:00:00
# 4           Baking  SHOT_010  20  REEL_01  2015-12-07 00:00:00
# 5            Paint  SHOT_010  20  REEL_01  2015-12-17 00:00:00
# 6               fx  SHOT_010  20  REEL_01          Not defined
# 7          Lookdev  SHOT_010  20  REEL_01  2015-12-14 00:00:00
# 8        Rendering  SHOT_010  20  REEL_01  2015-12-17 00:00:00
# 9      Compositing  SHOT_010  20  REEL_01  2015-12-17 00:00:00
# 10        Assemble  SHOT_025  30  REEL_01          Not defined
# 11           Cloth  SHOT_025  30  REEL_01          Not defined
# 12          Baking  SHOT_025  30  REEL_01          Not defined
# 13           Paint  SHOT_025  30  REEL_01          Not defined
# 14       Animation  SHOT_025  30  REEL_01  2015-08-03 00:00:00
# 15             Fur  SHOT_025  30  REEL_01          Not defined
# 16         Lookdev  SHOT_025  30  REEL_01          Not defined
# 17       Rendering  SHOT_025  30  REEL_01          Not defined
# 18     Compositing  SHOT_025  30  REEL_01          Not defined
# 19          Baking  SHOT_020  30  REEL_01          Not defined
# 20           Cloth  SHOT_020  30  REEL_01          Not defined
# 21        Assemble  SHOT_020  30  REEL_01          Not defined
# 22           Paint  SHOT_020  30  REEL_01          Not defined
# 23             Fur  SHOT_020  30  REEL_01          Not defined
# 24         Lookdev  SHOT_020  30  REEL_01          Not defined
# 25       Rendering  SHOT_020  30  REEL_01          Not defined
# 26     Compositing  SHOT_020  30  REEL_01          Not defined
# 27       Animation  SHOT_020  30  REEL_01  2015-08-03 00:00:00
# 28           Cloth  SHOT_010  30  REEL_01          Not defined
# 29     Compositing  SHOT_010  30  REEL_01          Not defined
# ...            ...       ...  ..      ...                  ...
# 4184   Compositing  SHOT_100  90  REEL_01          Not defined
# 4185         Paint  SHOT_100  90  REEL_01          Not defined
# 4186     Rendering  SHOT_100  90  REEL_01          Not defined
# 4187     Animation  SHOT_100  90  REEL_01  2015-12-04 00:00:00
# 4188       Lookdev  SHOT_100  90  REEL_01          Not defined
# 4189      Assemble  SHOT_100  90  REEL_01          Not defined
# 4190        Layout  SHOT_100  90  REEL_01  2015-12-02 00:00:00
# 4191         Cloth  SHOT_100  90  REEL_01          Not defined
# 4192        Baking  SHOT_100  90  REEL_01          Not defined
# 4193            FX  SHOT_040  90  REEL_01          Not defined
# 4194  Hair and Fur  SHOT_040  90  REEL_01          Not defined
# 4195   Compositing  SHOT_040  90  REEL_01          Not defined
# 4196         Paint  SHOT_040  90  REEL_01          Not defined
# 4197     Rendering  SHOT_040  90  REEL_01          Not defined
# 4198     Animation  SHOT_040  90  REEL_01  2015-12-04 00:00:00
# 4199       Lookdev  SHOT_040  90  REEL_01          Not defined
# 4200      Assemble  SHOT_040  90  REEL_01          Not defined
# 4201        Layout  SHOT_040  90  REEL_01          Not defined
# 4202         Cloth  SHOT_040  90  REEL_01          Not defined
# 4203        Baking  SHOT_040  90  REEL_01          Not defined
# 4204        layout  SHOT_090  90  REEL_01          Not defined
# 4205  hair and fur  SHOT_090  90  REEL_01          Not defined
# 4206         Cloth  SHOT_090  90  REEL_01          Not defined
# 4207   Compositing  SHOT_090  90  REEL_01          Not defined
# 4208         Paint  SHOT_090  90  REEL_01          Not defined
# 4209     Rendering  SHOT_090  90  REEL_01          Not defined
# 4210     Animation  SHOT_090  90  REEL_01  2015-12-04 00:00:00
# 4211       Lookdev  SHOT_090  90  REEL_01          Not defined
# 4212      Assemble  SHOT_090  90  REEL_01          Not defined
# 4213        Baking  SHOT_090  90  REEL_01          Not defined
#
#                   EndDate Duration
# 0     2015-12-02 00:00:00   1029.0
# 1     2015-12-12 00:00:00   1029.0
# 2             Not defined   1029.0
# 3     2015-12-08 00:00:00   1029.0
# 4     2015-12-08 00:00:00   1029.0
# 5     2015-12-21 00:00:00   1029.0
# 6             Not defined   1029.0
# 7     2015-12-16 00:00:00   1029.0
# 8     2015-12-21 00:00:00   1029.0
# 9     2015-12-21 00:00:00   1029.0
# 10            Not defined     71.0
# 11            Not defined     71.0
# 12            Not defined     71.0
# 13            Not defined     71.0
# 14    2015-09-02 12:00:00     71.0
# 15            Not defined     71.0
# 16            Not defined     71.0
# 17            Not defined     71.0
# 18            Not defined     71.0
# 19            Not defined    234.0
# 20            Not defined    234.0
# 21            Not defined    234.0
# 22            Not defined    234.0
# 23            Not defined    234.0
# 24            Not defined    234.0
# 25            Not defined    234.0
# 26            Not defined    234.0
# 27            Not defined    234.0
# 28            Not defined     83.0
# 29            Not defined     83.0
# ...                   ...      ...
# 4184          Not defined    189.0
# 4185          Not defined    189.0
# 4186          Not defined    189.0
# 4187          Not defined    189.0
# 4188          Not defined    189.0
# 4189          Not defined    189.0
# 4190  2015-12-05 00:00:00    189.0
# 4191          Not defined    189.0
# 4192          Not defined    189.0
# 4193          Not defined    373.0
# 4194          Not defined    373.0
# 4195          Not defined    373.0
# 4196          Not defined    373.0
# 4197          Not defined    373.0
# 4198  2016-04-06 21:00:00    373.0
# 4199          Not defined    373.0
# 4200          Not defined    373.0
# 4201          Not defined    373.0
# 4202          Not defined    373.0
# 4203          Not defined    373.0
# 4204  2015-12-05 00:00:00    310.0
# 4205          Not defined    310.0
# 4206          Not defined    310.0
# 4207          Not defined    310.0
# 4208          Not defined    310.0
# 4209          Not defined    310.0
# 4210          Not defined    310.0
# 4211          Not defined    310.0
# 4212          Not defined    310.0
# 4213          Not defined    310.0
#
# [4214 rows x 7 columns]

# %%
#Connect to ORM system
import sys
sys.path.append("C:/Users/i.podmokov/Desktop/Info Flask")
from app import model,db

# %%
#typecasting of DataFrame 
dDict = df_1.to_dict()
d_2Dict = df_2.to_dict()
type(dDict['Duration'][1])
# Out:
# str

# %%
'''
for i in df_1.to_dict()['Duration'].keys():
    t = model.Tasks(name = dDict['Name'][i],reel = dDict['Reel'][i],seq = dDict['Seq'][i], shot = dDict['Shot'][i],start_date = dDict['StartDate'][i],end_date = dDict['EndDate'][i],duration = dDict['Duration'][i])
    w = model.WorkFlow(status = d_2Dict['Status'][i],fill_date =d_2Dict['FillDate'][i], task = t)
    db.session.add(t)
    db.session.add(w)
    db.session.commit()
'''

# %%
db.session.rollback()

# %%
t = model.Tasks(name = dDict['Name'][4],reel = dDict['Reel'][4],seq = dDict['Seq'][4], shot = dDict['Shot'][4],start_date = dDict['StartDate'][4],end_date = dDict['EndDate'][4],duration = dDict['Duration'][4])
w = model.WorkFlow(status = d_2Dict['Status'][4],fill_date =d_2Dict['FillDate'][4], task = t)
db.session.add(t)
db.session.add(w)
db.session.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-50-966ca34feab4> in <module>()
#       3 db.session.add(t)
#       4 db.session.add(w)
# ----> 5 db.session.commit()
#
# c:\python27\lib\site-packages\sqlalchemy\orm\scoping.pyc in do(self, *args, **kwargs)
#     155 def instrument(name):
#     156     def do(self, *args, **kwargs):
# --> 157         return getattr(self.registry(), name)(*args, **kwargs)
#     158     return do
#     159
#
# c:\python27\lib\site-packages\sqlalchemy\orm\session.pyc in commit(self)
#     799                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#     800
# --> 801         self.transaction.commit()
#     802
#     803     def prepare(self):
#
# c:\python27\lib\site-packages\sqlalchemy\orm\session.pyc in commit(self)
#     390         self._assert_active(prepared_ok=True)
#     391         if self._state is not PREPARED:
# --> 392             self._prepare_impl()
#     393
#     394         if self._parent is None or self.nested:
#
# c:\python27\lib\site-packages\sqlalchemy\orm\session.pyc in _prepare_impl(self)
#     370                 if self.session._is_clean():
#     371                     break
# --> 372                 self.session.flush()
#     373             else:
#     374                 raise exc.FlushError(
#
# c:\python27\lib\site-packages\sqlalchemy\orm\session.pyc in flush(self, objects)
#    2017         try:
#    2018             self._flushing = True
# -> 2019             self._flush(objects)
#    2020         finally:
#    2021             self._flushing = False
#
# c:\python27\lib\site-packages\sqlalchemy\orm\session.pyc in _flush(self, objects)
#    2135         except:
#    2136             with util.safe_reraise():
# -> 2137                 transaction.rollback(_capture_exception=True)
#    2138
#    2139     def bulk_save_objects(
#
# c:\python27\lib\site-packages\sqlalchemy\util\langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# c:\python27\lib\site-packages\sqlalchemy\orm\session.pyc in _flush(self, objects)
#    2099             self._warn_on_events = True
#    2100             try:
# -> 2101                 flush_context.execute()
#    2102             finally:
#    2103                 self._warn_on_events = False
#
# c:\python27\lib\site-packages\sqlalchemy\orm\unitofwork.pyc in execute(self)
#     371                     self.dependencies,
#     372                     postsort_actions):
# --> 373                 rec.execute(self)
#     374
#     375     def finalize_flush_changes(self):
#
# c:\python27\lib\site-packages\sqlalchemy\orm\unitofwork.pyc in execute(self, uow)
#     530                              uow.states_for_mapper_hierarchy(
#     531                                  self.mapper, False, False),
# --> 532                              uow
#     533                              )
#     534
#
# c:\python27\lib\site-packages\sqlalchemy\orm\persistence.pyc in save_obj(base_mapper, states, uowtransaction, single)
#     172         _emit_insert_statements(base_mapper, uowtransaction,
#     173                                 cached_connections,
# --> 174                                 mapper, table, insert)
#     175
#     176     _finalize_insert_update_commands(
#
# c:\python27\lib\site-packages\sqlalchemy\orm\persistence.pyc in _emit_insert_statements(base_mapper, uowtransaction, cached_connections, mapper, table, insert, bookkeeping)
#     798                 else:
#     799                     result = cached_connections[connection].\
# --> 800                         execute(statement, params)
#     801
#     802                 primary_key = result.context.inserted_primary_key
#
# c:\python27\lib\site-packages\sqlalchemy\engine\base.pyc in execute(self, object, *multiparams, **params)
#     912                 type(object))
#     913         else:
# --> 914             return meth(self, multiparams, params)
#     915
#     916     def _execute_function(self, func, multiparams, params):
#
# c:\python27\lib\site-packages\sqlalchemy\sql\elements.pyc in _execute_on_connection(self, connection, multiparams, params)
#     321
#     322     def _execute_on_connection(self, connection, multiparams, params):
# --> 323         return connection._execute_clauseelement(self, multiparams, params)
#     324
#     325     def unique_params(self, *optionaldict, **kwargs):
#
# c:\python27\lib\site-packages\sqlalchemy\engine\base.pyc in _execute_clauseelement(self, elem, multiparams, params)
#    1008             compiled_sql,
#    1009             distilled_params,
# -> 1010             compiled_sql, distilled_params
#    1011         )
#    1012         if self._has_events or self.engine._has_events:
#
# c:\python27\lib\site-packages\sqlalchemy\engine\base.pyc in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1144                 parameters,
#    1145                 cursor,
# -> 1146                 context)
#    1147
#    1148         if self._has_events or self.engine._has_events:
#
# c:\python27\lib\site-packages\sqlalchemy\engine\base.pyc in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1339                 util.raise_from_cause(
#    1340                     sqlalchemy_exception,
# -> 1341                     exc_info
#    1342                 )
#    1343             else:
#
# c:\python27\lib\site-packages\sqlalchemy\util\compat.pyc in raise_from_cause(exception, exc_info)
#     200     exc_type, exc_value, exc_tb = exc_info
#     201     cause = exc_value if exc_value is not exception else None
# --> 202     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     203
#     204 if py3k:
#
# c:\python27\lib\site-packages\sqlalchemy\engine\base.pyc in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1137                         statement,
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#    1141             self._handle_dbapi_exception(
#
# c:\python27\lib\site-packages\sqlalchemy\engine\default.pyc in do_execute(self, cursor, statement, parameters, context)
#     448
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#     452     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: tasks [SQL: u'INSERT INTO tasks (name, shot, seq, reel, start_date, end_date, duration) VALUES (?, ?, ?, ?, ?, ?, ?)'] [parameters: ('Assemble', 'SHOT_010', '20', 'REEL_01', 'Not defined', 'Not defined', '1029.0')]

# %%
model.Tasks.query.all()
# Out:
# Task u'Fur' u'SHOT_010' u'20' u'REEL_01' u'2015-12-10 00:00:00' u'2015-12-12 00:00:00' u'1029.0'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\python27\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     668                 type_pprinters=self.type_printers,
#     669                 deferred_pprinters=self.deferred_printers)
# --> 670             printer.pretty(obj)
#     671             printer.flush()
#     672             return stream.getvalue()
#
# c:\python27\lib\site-packages\IPython\lib\pretty.pyc in pretty(self, obj)
#     366                 if cls in self.type_pprinters:
#     367                     # printer registered in self.type_pprinters
# --> 368                     return self.type_pprinters[cls](obj, self, cycle)
#     369                 else:
#     370                     # deferred printer
#
# c:\python27\lib\site-packages\IPython\lib\pretty.pyc in inner(obj, p, cycle)
#     550                 p.text(',')
#     551                 p.breakable()
# --> 552             p.pretty(x)
#     553         if len(obj) == 1 and type(obj) is tuple:
#     554             # Special case for 1-item tuples.
#
# c:\python27\lib\site-packages\IPython\lib\pretty.pyc in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# c:\python27\lib\site-packages\IPython\lib\pretty.pyc in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# c:\python27\lib\site-packages\IPython\lib\pretty.pyc in _repr_pprint(obj, p, cycle)
#     692     """A pprint that just redirects to the normal repr function."""
#     693     # Find newlines and replace them with p.break_()
# --> 694     output = repr(obj)
#     695     for idx,output_line in enumerate(output.splitlines()):
#     696         if idx:
#
# TypeError: __repr__ returned non-string (type NoneType)
